# %%
# Salva modelo
model_path = Path('../models/modelo_risco_defasagem.pkl')
model_path.parent.mkdir(exist_ok=True)

with open(model_path, 'wb') as f:
    pickle.dump(best_model, f)

print(f"Modelo salvo em: {model_path}")
print(f"\nModelo: {best_model_name}")
print(f"ROC-AUC: {results[best_model_name]['roc_auc']:.3f}")
print(f"Acurácia: {results[best_model_name]['accuracy']:.3f}")

# %% [markdown]
# ## 9. Conclusões
#
# ### Resultados Principais:
#
# 1. **Melhor Modelo:** Hist Gradient Boosting
# 2. **Performance:**
#    - Acurácia: 77.2%
#    - ROC-AUC: 83.9%
# 3. **Feature Mais Importante:** Idade
# 4. **Insights:**
#    - O modelo consegue identificar alunos em risco com boa precisão
#    - Idade é o fator mais crítico para risco de defasagem
#    - Média acadêmica e tempo na escola também são importantes
#
# ### Próximos Passos:
#
# - Modelo disponibilizado na aplicação Streamlit
# - Pode ser usado pela Passos Mágicos para identificar alunos em risco
# - Permite intervenção preventiva
